# %%
import requests
import numpy as np
import pandas as pd
import time
from pprint import pprint
from matplotlib import pyplot as plt
from scipy import stats

# %% [markdown]
#
# # ERD (Lucidchart url)
# #https://lucid.app/lucidchart/invitations/accept/inv_16bcc521-d101-44d3-a823-5e6a897cfaf2

# %%
apikey = "15B191E7-B8C5-3AF1-9E28-97FD910F9119"
usda_url ="http://quickstats.nass.usda.gov/api/api_GET/?key=15B191E7-B8C5-3AF1-9E28-97FD910F9119&source_desc=SURVEY&commodity_desc=HONEY&agg_level_desc=STATE&param=short_desc"
usda_data= requests.get(usda_url).json()
usda_data
# Out:
# {'data': [{'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'agg_level_desc': 'STATE',
#    'state_name': 'ALABAMA',
#    'state_alpha': 'AL',
#    'CV (%)': '',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '01',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '01',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'location_desc': 'ALABAMA',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'Value': '5.43',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2020},
#   {'year': 2019,
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '3.38',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'location_desc': 'ALABAMA',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'state_fips_code': '01',
#    'source_desc': 'SURVEY',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_ansi': '01',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'CV (%)': '',
#    'state_alpha': 'AL',
#    'state_name': 'ALABAMA',
#    'agg_level_desc': 'STATE',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL'},
#   {'Value': '3.72',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2018,
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'unit_desc': '$ / LB',
#    'location_desc': 'ALABAMA',
#    'county_ansi': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'country_name': 'UNITED STATES',
#    'load_time': '2020-03-19 15:06:59',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '01',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '01',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'agg_level_desc': 'STATE',
#    'state_name': 'ALABAMA',
#    'CV (%)': '',
#    'state_alpha': 'AL'},
#   {'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'location_desc': 'ARIZONA',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'year': 2020,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'Value': '2.18',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'state_name': 'ARIZONA',
#    'agg_level_desc': 'STATE',
#    'CV (%)': '',
#    'state_alpha': 'AZ',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_ansi': '04',
#    'state_fips_code': '04',
#    'source_desc': 'SURVEY',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29'},
#   {'location_desc': 'ARIZONA',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.04',
#    'year': 2019,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'AZ',
#    'CV (%)': '',
#    'state_name': 'ARIZONA',
#    'agg_level_desc': 'STATE',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'state_fips_code': '04',
#    'source_desc': 'SURVEY',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_ansi': '04'},
#   {'state_fips_code': '04',
#    'source_desc': 'SURVEY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'region_desc': '',
#    'state_ansi': '04',
#    'commodity_desc': 'HONEY',
#    'load_time': '2020-03-19 15:06:59',
#    'country_name': 'UNITED STATES',
#    'CV (%)': '',
#    'state_alpha': 'AZ',
#    'state_name': 'ARIZONA',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'year': 2018,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '3.01',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_ansi': '',
#    'location_desc': 'ARIZONA',
#    'unit_desc': '$ / LB',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': ''},
#   {'CV (%)': '',
#    'state_alpha': 'AR',
#    'state_name': 'ARKANSAS',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'state_fips_code': '05',
#    'source_desc': 'SURVEY',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_ansi': '05',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_ansi': '',
#    'location_desc': 'ARKANSAS',
#    'unit_desc': '$ / LB',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'year': 2020,
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '1.8'},
#   {'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '1.65',
#    'year': 2019,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'county_code': '',
#    'zip_5': '',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'location_desc': 'ARKANSAS',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'state_fips_code': '05',
#    'source_desc': 'SURVEY',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_ansi': '05',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'AR',
#    'CV (%)': '',
#    'state_name': 'ARKANSAS',
#    'agg_level_desc': 'STATE'},
#   {'source_desc': 'SURVEY',
#    'state_fips_code': '05',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '05',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2020-03-19 15:06:59',
#    'CV (%)': '',
#    'state_alpha': 'AR',
#    'state_name': 'ARKANSAS',
#    'agg_level_desc': 'STATE',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2018,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '1.88',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'ARKANSAS',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00'},
#   {'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2020,
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '1.78',
#    'week_ending': '',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'location_desc': 'CALIFORNIA',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '06',
#    'state_ansi': '06',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'commodity_desc': 'HONEY',
#    'state_alpha': 'CA',
#    'CV (%)': '',
#    'agg_level_desc': 'STATE',
#    'state_name': 'CALIFORNIA',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': ''},
#   {'Value': '1.6',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'class_desc': 'ALL CLASSES',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'year': 2019,
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'CALIFORNIA',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '06',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_fips_code': '06',
#    'source_desc': 'SURVEY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'agg_level_desc': 'STATE',
#    'state_name': 'CALIFORNIA',
#    'CV (%)': '',
#    'state_alpha': 'CA'},
#   {'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.11',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2018,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'location_desc': 'CALIFORNIA',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'commodity_desc': 'HONEY',
#    'load_time': '2020-03-19 15:06:59',
#    'country_name': 'UNITED STATES',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '06',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '06',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'CV (%)': '',
#    'state_alpha': 'CA',
#    'state_name': 'CALIFORNIA',
#    'agg_level_desc': 'STATE'},
#   {'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'location_desc': 'COLORADO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2020,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.09',
#    'state_alpha': 'CO',
#    'CV (%)': '',
#    'state_name': 'COLORADO',
#    'agg_level_desc': 'STATE',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '08',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '08',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES'},
#   {'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.34',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2019,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'location_desc': 'COLORADO',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '08',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'state_ansi': '08',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_alpha': 'CO',
#    'CV (%)': '',
#    'state_name': 'COLORADO',
#    'agg_level_desc': 'STATE'},
#   {'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'COLORADO',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2018,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.05',
#    'CV (%)': '',
#    'state_alpha': 'CO',
#    'state_name': 'COLORADO',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '08',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '08',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2020-03-19 15:06:59'},
#   {'county_ansi': '',
#    'location_desc': 'FLORIDA',
#    'unit_desc': '$ / LB',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.28',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2020,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_alpha': 'FL',
#    'CV (%)': '',
#    'state_name': 'FLORIDA',
#    'agg_level_desc': 'STATE',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '12',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'state_ansi': '12'},
#   {'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'county_ansi': '',
#    'location_desc': 'FLORIDA',
#    'unit_desc': '$ / LB',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'week_ending': '',
#    'Value': '2.46',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2019,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_name': 'FLORIDA',
#    'agg_level_desc': 'STATE',
#    'state_alpha': 'FL',
#    'CV (%)': '',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'state_ansi': '12',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '12'},
#   {'agg_level_desc': 'STATE',
#    'state_name': 'FLORIDA',
#    'CV (%)': '',
#    'state_alpha': 'FL',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_ansi': '12',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '12',
#    'country_name': 'UNITED STATES',
#    'load_time': '2020-03-19 15:06:59',
#    'commodity_desc': 'HONEY',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'location_desc': 'FLORIDA',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2018,
#    'Value': '2.4',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'year': 2020,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.36',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'GEORGIA',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'state_fips_code': '13',
#    'source_desc': 'SURVEY',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'region_desc': '',
#    'state_ansi': '13',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'CV (%)': '',
#    'state_alpha': 'GA',
#    'state_name': 'GEORGIA',
#    'agg_level_desc': 'STATE',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL'},
#   {'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.67',
#    'year': 2019,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'GEORGIA',
#    'unit_desc': '$ / LB',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'state_fips_code': '13',
#    'source_desc': 'SURVEY',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_ansi': '13',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'GA',
#    'CV (%)': '',
#    'state_name': 'GEORGIA',
#    'agg_level_desc': 'STATE'},
#   {'state_ansi': '13',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_fips_code': '13',
#    'source_desc': 'SURVEY',
#    'load_time': '2020-03-19 15:06:59',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'agg_level_desc': 'STATE',
#    'state_name': 'GEORGIA',
#    'CV (%)': '',
#    'state_alpha': 'GA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'country_code': '9000',
#    'county_code': '',
#    'zip_5': '',
#    'class_desc': 'ALL CLASSES',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'year': 2018,
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'Value': '2.76',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'location_desc': 'GEORGIA'},
#   {'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'unit_desc': '$ / LB',
#    'location_desc': 'HAWAII',
#    'county_ansi': '',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2020,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '1.61',
#    'state_alpha': 'HI',
#    'CV (%)': '',
#    'state_name': 'HAWAII',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '15',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '15',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES'},
#   {'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2019,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '1.3',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'HAWAII',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '15',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '15',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'CV (%)': '',
#    'state_alpha': 'HI',
#    'state_name': 'HAWAII',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'location_desc': 'HAWAII',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'class_desc': 'ALL CLASSES',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'year': 2018,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'Value': '1.92',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'agg_level_desc': 'STATE',
#    'state_name': 'HAWAII',
#    'CV (%)': '',
#    'state_alpha': 'HI',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_ansi': '15',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_fips_code': '15',
#    'source_desc': 'SURVEY',
#    'load_time': '2020-03-19 15:06:59',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY'},
#   {'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'CV (%)': '',
#    'state_alpha': 'ID',
#    'state_name': 'IDAHO',
#    'agg_level_desc': 'STATE',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '16',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '16',
#    'location_desc': 'IDAHO',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '1.75',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2020,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000'},
#   {'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'IDAHO',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'Value': '1.62',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'county_code': '',
#    'zip_5': '',
#    'class_desc': 'ALL CLASSES',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'year': 2019,
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'agg_level_desc': 'STATE',
#    'state_name': 'IDAHO',
#    'state_alpha': 'ID',
#    'CV (%)': '',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '16',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'region_desc': '',
#    'state_fips_code': '16',
#    'source_desc': 'SURVEY'},
#   {'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'CV (%)': '',
#    'state_alpha': 'ID',
#    'state_name': 'IDAHO',
#    'agg_level_desc': 'STATE',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2020-03-19 15:06:59',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '16',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'state_ansi': '16',
#    'location_desc': 'IDAHO',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '1.96',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2018,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000'},
#   {'source_desc': 'SURVEY',
#    'state_fips_code': '17',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '17',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'CV (%)': '',
#    'state_alpha': 'IL',
#    'state_name': 'ILLINOIS',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2020,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '5.56',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_ansi': '',
#    'location_desc': 'ILLINOIS',
#    'unit_desc': '$ / LB',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00'},
#   {'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_ansi': '17',
#    'state_fips_code': '17',
#    'source_desc': 'SURVEY',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'state_name': 'ILLINOIS',
#    'agg_level_desc': 'STATE',
#    'state_alpha': 'IL',
#    'CV (%)': '',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'year': 2019,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'Value': '4.12',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'ILLINOIS',
#    'county_ansi': '',
#    'unit_desc': '$ / LB'},
#   {'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2018,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '4.83',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'location_desc': 'ILLINOIS',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '17',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'state_ansi': '17',
#    'commodity_desc': 'HONEY',
#    'load_time': '2020-03-19 15:06:59',
#    'country_name': 'UNITED STATES',
#    'CV (%)': '',
#    'state_alpha': 'IL',
#    'state_name': 'ILLINOIS',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED'},
#   {'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2020,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '4.14',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'INDIANA',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '18',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '18',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'CV (%)': '',
#    'state_alpha': 'IN',
#    'state_name': 'INDIANA',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED'},
#   {'source_desc': 'SURVEY',
#    'state_fips_code': '18',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'state_ansi': '18',
#    'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'state_alpha': 'IN',
#    'CV (%)': '',
#    'state_name': 'INDIANA',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2019,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '3.78',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'INDIANA',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00'},
#   {'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'location_desc': 'INDIANA',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'Value': '3.58',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2018,
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'agg_level_desc': 'STATE',
#    'state_name': 'INDIANA',
#    'state_alpha': 'IN',
#    'CV (%)': '',
#    'load_time': '2020-03-19 15:06:59',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '18',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '18'},
#   {'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'class_desc': 'ALL CLASSES',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'year': 2020,
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'Value': '2.59',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'unit_desc': '$ / LB',
#    'location_desc': 'IOWA',
#    'county_ansi': '',
#    'state_ansi': '19',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_fips_code': '19',
#    'source_desc': 'SURVEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'agg_level_desc': 'STATE',
#    'state_name': 'IOWA',
#    'state_alpha': 'IA',
#    'CV (%)': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR'},
#   {'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'agg_level_desc': 'STATE',
#    'state_name': 'IOWA',
#    'CV (%)': '',
#    'state_alpha': 'IA',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '19',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'region_desc': '',
#    'state_fips_code': '19',
#    'source_desc': 'SURVEY',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'location_desc': 'IOWA',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'Value': '2.35',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'class_desc': 'ALL CLASSES',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'year': 2019,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00'},
#   {'state_name': 'IOWA',
#    'agg_level_desc': 'STATE',
#    'CV (%)': '',
#    'state_alpha': 'IA',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'region_desc': '',
#    'state_ansi': '19',
#    'state_fips_code': '19',
#    'source_desc': 'SURVEY',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2020-03-19 15:06:59',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'location_desc': 'IOWA',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2018,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'Value': '2.4',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '20',
#    'state_ansi': '20',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'state_alpha': 'KS',
#    'CV (%)': '',
#    'agg_level_desc': 'STATE',
#    'state_name': 'KANSAS',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '2.93',
#    'week_ending': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2020,
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'location_desc': 'KANSAS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': ''},
#   {'state_fips_code': '20',
#    'source_desc': 'SURVEY',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'region_desc': '',
#    'state_ansi': '20',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2021-03-18 15:00:29',
#    'state_alpha': 'KS',
#    'CV (%)': '',
#    'state_name': 'KANSAS',
#    'agg_level_desc': 'STATE',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'year': 2019,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '2.35',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'unit_desc': '$ / LB',
#    'location_desc': 'KANSAS',
#    'county_ansi': '',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'unit_desc': '$ / LB',
#    'location_desc': 'KANSAS',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '3.1',
#    'week_ending': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2018,
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'state_alpha': 'KS',
#    'CV (%)': '',
#    'agg_level_desc': 'STATE',
#    'state_name': 'KANSAS',
#    'country_name': 'UNITED STATES',
#    'load_time': '2020-03-19 15:06:59',
#    'commodity_desc': 'HONEY',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '20',
#    'state_ansi': '20',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'begin_code': '00',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'KENTUCKY',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'class_desc': 'ALL CLASSES',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'year': 2020,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'Value': '6.25',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'agg_level_desc': 'STATE',
#    'state_name': 'KENTUCKY',
#    'CV (%)': '',
#    'state_alpha': 'KY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_ansi': '21',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'region_desc': '',
#    'state_fips_code': '21',
#    'source_desc': 'SURVEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY'},
#   {'commodity_desc': 'HONEY',
#    'load_time': '2021-03-18 15:00:29',
#    'country_name': 'UNITED STATES',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '21',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'state_ansi': '21',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'CV (%)': '',
#    'state_alpha': 'KY',
#    'state_name': 'KENTUCKY',
#    'agg_level_desc': 'STATE',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '4.66',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2019,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'location_desc': 'KENTUCKY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS'},
#   {'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '5.43',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2018,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'location_desc': 'KENTUCKY',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'commodity_desc': 'HONEY',
#    'load_time': '2020-03-19 15:06:59',
#    'country_name': 'UNITED STATES',
# ...
#    'state_ansi': '38',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2012-01-01 00:00:00',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'county_ansi': '',
#    'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'year': 2010,
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'week_ending': '',
#    'Value': '150',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'county_ansi': '',
#    'unit_desc': 'CENTS / LB',
#    'location_desc': 'NORTH DAKOTA',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '138',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'year': 2009,
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'class_desc': 'ALL CLASSES',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'CV (%)': '',
#    'state_alpha': 'ND',
#    'agg_level_desc': 'STATE',
#    'state_name': 'NORTH DAKOTA',
#    'country_name': 'UNITED STATES',
#    'load_time': '2012-01-01 00:00:00',
#    'commodity_desc': 'HONEY',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'region_desc': ''},
#   {'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'state_ansi': '38',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'country_name': 'UNITED STATES',
#    'load_time': '2012-01-01 00:00:00',
#    'commodity_desc': 'HONEY',
#    'CV (%)': '',
#    'state_alpha': 'ND',
#    'agg_level_desc': 'STATE',
#    'state_name': 'NORTH DAKOTA',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2008,
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '136',
#    'week_ending': '',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'unit_desc': 'CENTS / LB',
#    'location_desc': 'NORTH DAKOTA',
#    'county_ansi': '',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'location_desc': 'NORTH DAKOTA',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2007,
#    'Value': '96',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'agg_level_desc': 'STATE',
#    'state_name': 'NORTH DAKOTA',
#    'state_alpha': 'ND',
#    'CV (%)': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_ansi': '38',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'load_time': '2012-01-01 00:00:00',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY'},
#   {'CV (%)': '',
#    'state_alpha': 'ND',
#    'state_name': 'NORTH DAKOTA',
#    'agg_level_desc': 'STATE',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '38',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2012-01-01 00:00:00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2006,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '91'},
#   {'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'agg_level_desc': 'STATE',
#    'state_name': 'NORTH DAKOTA',
#    'state_alpha': 'ND',
#    'CV (%)': '',
#    'load_time': '2012-01-01 00:00:00',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '38',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'location_desc': 'NORTH DAKOTA',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'Value': '83',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2005},
#   {'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'state_ansi': '38',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'country_name': 'UNITED STATES',
#    'load_time': '2012-01-01 00:00:00',
#    'commodity_desc': 'HONEY',
#    'state_alpha': 'ND',
#    'CV (%)': '',
#    'agg_level_desc': 'STATE',
#    'state_name': 'NORTH DAKOTA',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2004,
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '105',
#    'week_ending': '',
#    'county_name': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00'},
#   {'state_alpha': 'ND',
#    'CV (%)': '',
#    'state_name': 'NORTH DAKOTA',
#    'agg_level_desc': 'STATE',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'freq_desc': 'ANNUAL',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'region_desc': '',
#    'state_ansi': '38',
#    'commodity_desc': 'HONEY',
#    'load_time': '2012-01-01 00:00:00',
#    'country_name': 'UNITED STATES',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'begin_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'year': 2003,
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'country_code': '9000',
#    'zip_5': '',
#    'county_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '136'},
#   {'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2002,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'Value': '146',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'location_desc': 'NORTH DAKOTA',
#    'county_ansi': '',
#    'unit_desc': 'CENTS / LB',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'commodity_desc': 'HONEY',
#    'country_name': 'UNITED STATES',
#    'load_time': '2012-01-01 00:00:00',
#    'state_name': 'NORTH DAKOTA',
#    'agg_level_desc': 'STATE',
#    'state_alpha': 'ND',
#    'CV (%)': '',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': ''},
#   {'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '69',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'year': 2001,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'CV (%)': '',
#    'state_alpha': 'ND',
#    'state_name': 'NORTH DAKOTA',
#    'agg_level_desc': 'STATE',
#    'commodity_desc': 'HONEY',
#    'load_time': '2012-01-01 00:00:00',
#    'country_name': 'UNITED STATES',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '38'},
#   {'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'state_ansi': '38',
#    'commodity_desc': 'HONEY',
#    'load_time': '2012-01-01 00:00:00',
#    'country_name': 'UNITED STATES',
#    'state_alpha': 'ND',
#    'CV (%)': '',
#    'state_name': 'NORTH DAKOTA',
#    'agg_level_desc': 'STATE',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 2000,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'week_ending': '',
#    'Value': '57',
#    'county_name': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00'},
#   {'Value': '59',
#    'week_ending': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 1999,
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'congr_district_code': '',
#    'begin_code': '00',
#    'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_code': '',
#    'county_name': '',
#    'load_time': '2012-01-01 00:00:00',
#    'country_name': 'UNITED STATES',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '38',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'watershed_code': '00000000',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'asd_desc': '',
#    'watershed_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'agg_level_desc': 'STATE',
#    'state_name': 'NORTH DAKOTA',
#    'state_alpha': 'ND',
#    'CV (%)': ''},
#   {'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'county_ansi': '',
#    'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'week_ending': '',
#    'Value': '63',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'class_desc': 'ALL CLASSES',
#    'zip_5': '',
#    'county_code': '',
#    'country_code': '9000',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 1998,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_name': 'NORTH DAKOTA',
#    'agg_level_desc': 'STATE',
#    'CV (%)': '',
#    'state_alpha': 'ND',
#    'commodity_desc': 'HONEY',
#    'load_time': '2012-01-01 00:00:00',
#    'country_name': 'UNITED STATES',
#    'region_desc': '',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38'},
#   {'asd_desc': '',
#    'freq_desc': 'ANNUAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'reference_period_desc': 'MARKETING YEAR',
#    'watershed_desc': '',
#    'state_name': 'NORTH DAKOTA',
#    'agg_level_desc': 'STATE',
#    'state_alpha': 'ND',
#    'CV (%)': '',
#    'commodity_desc': 'HONEY',
#    'load_time': '2012-01-01 00:00:00',
#    'country_name': 'UNITED STATES',
#    'region_desc': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'congr_district_code': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'begin_code': '00',
#    'location_desc': 'NORTH DAKOTA',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'asd_code': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'county_name': '',
#    'week_ending': '',
#    'Value': '74',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'class_desc': 'ALL CLASSES',
#    'county_code': '',
#    'zip_5': '',
#    'country_code': '9000',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'year': 1997,
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED'},
#   ...]}

# %% [markdown]
# # Created a dataframe using the downloaded data

# %%
new_usda_list=usda_data['data']
usda_df=pd.DataFrame(new_usda_list)
usda_df.head(2)
usda_df.head(2)
# Out:
#   freq_desc domaincat_desc asd_desc reference_period_desc watershed_desc  \
# 0    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 1    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
#
#   agg_level_desc state_name state_alpha CV (%)            load_time  ...  \
# 0          STATE    ALABAMA          AL         2021-03-18 15:00:29  ...
# 1          STATE    ALABAMA          AL         2021-03-18 15:00:29  ...
#
#           util_practice_desc county_code zip_5 country_code   class_desc  \
# 0  ALL UTILIZATION PRACTICES                           9000  ALL CLASSES
# 1  ALL UTILIZATION PRACTICES                           9000  ALL CLASSES
#
#   domain_desc statisticcat_desc group_desc end_code  year
# 0       TOTAL    PRICE RECEIVED  SPECIALTY       00  2020
# 1       TOTAL    PRICE RECEIVED  SPECIALTY       00  2019
#
# [2 rows x 39 columns]

# %% [markdown]
# # Viewed columns in order to create a column for a survey id unique to the survey for each state and time period

# %%
usda_df.columns
# Out:
# Index(['freq_desc', 'domaincat_desc', 'asd_desc', 'reference_period_desc',
#        'watershed_desc', 'agg_level_desc', 'state_name', 'state_alpha',
#        'CV (%)', 'load_time', 'country_name', 'commodity_desc', 'state_ansi',
#        'region_desc', 'short_desc', 'watershed_code', 'source_desc',
#        'state_fips_code', 'prodn_practice_desc', 'congr_district_code',
#        'begin_code', 'location_desc', 'unit_desc', 'county_ansi',
#        'sector_desc', 'asd_code', 'county_name', 'Value', 'week_ending',
#        'util_practice_desc', 'county_code', 'zip_5', 'country_code',
#        'class_desc', 'domain_desc', 'statisticcat_desc', 'group_desc',
#        'end_code', 'year'],
#       dtype='object')

# %%
usda_df.reset_index(inplace=True)
usda_df = usda_df.rename(columns = {'index': 'survey_id'})
usda_df.reset_index(drop=True)
usda_df
# Out:
#        survey_id freq_desc domaincat_desc asd_desc reference_period_desc  \
# 0              0    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 1              1    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 2              2    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 3              3    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 4              4    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# ...          ...       ...            ...      ...                   ...
# 21637      21637   MONTHLY  NOT SPECIFIED                   OCT THRU DEC
# 21638      21638   MONTHLY  NOT SPECIFIED                   JAN THRU MAR
# 21639      21639   MONTHLY  NOT SPECIFIED                   APR THRU JUN
# 21640      21640   MONTHLY  NOT SPECIFIED                   JUL THRU SEP
# 21641      21641   MONTHLY  NOT SPECIFIED                   OCT THRU DEC
#
#       watershed_desc agg_level_desc    state_name state_alpha CV (%)  ...  \
# 0                             STATE       ALABAMA          AL         ...
# 1                             STATE       ALABAMA          AL         ...
# 2                             STATE       ALABAMA          AL         ...
# 3                             STATE       ARIZONA          AZ         ...
# 4                             STATE       ARIZONA          AZ         ...
# ...              ...            ...           ...         ...    ...  ...
# 21637                         STATE  OTHER STATES          OT         ...
# 21638                         STATE  OTHER STATES          OT         ...
# 21639                         STATE  OTHER STATES          OT         ...
# 21640                         STATE  OTHER STATES          OT         ...
# 21641                         STATE  OTHER STATES          OT         ...
#
#               util_practice_desc county_code zip_5 country_code    class_desc  \
# 0      ALL UTILIZATION PRACTICES                           9000   ALL CLASSES
# 1      ALL UTILIZATION PRACTICES                           9000   ALL CLASSES
# 2      ALL UTILIZATION PRACTICES                           9000   ALL CLASSES
# 3      ALL UTILIZATION PRACTICES                           9000   ALL CLASSES
# 4      ALL UTILIZATION PRACTICES                           9000   ALL CLASSES
# ...                          ...         ...   ...          ...           ...
# 21637  ALL UTILIZATION PRACTICES                           9000  BEE COLONIES
# 21638  ALL UTILIZATION PRACTICES                           9000  BEE COLONIES
# 21639  ALL UTILIZATION PRACTICES                           9000  BEE COLONIES
# 21640  ALL UTILIZATION PRACTICES                           9000  BEE COLONIES
# 21641  ALL UTILIZATION PRACTICES                           9000  BEE COLONIES
#
#       domain_desc statisticcat_desc group_desc end_code  year
# 0           TOTAL    PRICE RECEIVED  SPECIALTY       00  2020
# 1           TOTAL    PRICE RECEIVED  SPECIALTY       00  2019
# 2           TOTAL    PRICE RECEIVED  SPECIALTY       00  2018
# 3           TOTAL    PRICE RECEIVED  SPECIALTY       00  2020
# 4           TOTAL    PRICE RECEIVED  SPECIALTY       00  2019
# ...           ...               ...        ...      ...   ...
# 21637       TOTAL         INVENTORY  SPECIALTY       12  2016
# 21638       TOTAL         INVENTORY  SPECIALTY       03  2015
# 21639       TOTAL         INVENTORY  SPECIALTY       06  2015
# 21640       TOTAL         INVENTORY  SPECIALTY       09  2015
# 21641       TOTAL         INVENTORY  SPECIALTY       12  2015
#
# [21642 rows x 40 columns]

# %% [markdown]
# # Generated the marketing ids by concatenating a code for the reference period description, state abbreviation, and year.

# %%
# concatenating the columns
usda_df['marketing_id'] = usda_df['reference_period_desc'].map(str) + usda_df['state_alpha'].map(str)+usda_df['year'].map(str)
usda_df
# Out:
#        survey_id freq_desc domaincat_desc asd_desc reference_period_desc  \
# 0              0    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 1              1    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 2              2    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 3              3    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 4              4    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# ...          ...       ...            ...      ...                   ...
# 21637      21637   MONTHLY  NOT SPECIFIED                   OCT THRU DEC
# 21638      21638   MONTHLY  NOT SPECIFIED                   JAN THRU MAR
# 21639      21639   MONTHLY  NOT SPECIFIED                   APR THRU JUN
# 21640      21640   MONTHLY  NOT SPECIFIED                   JUL THRU SEP
# 21641      21641   MONTHLY  NOT SPECIFIED                   OCT THRU DEC
#
#       watershed_desc agg_level_desc    state_name state_alpha CV (%)  ...  \
# 0                             STATE       ALABAMA          AL         ...
# 1                             STATE       ALABAMA          AL         ...
# 2                             STATE       ALABAMA          AL         ...
# 3                             STATE       ARIZONA          AZ         ...
# 4                             STATE       ARIZONA          AZ         ...
# ...              ...            ...           ...         ...    ...  ...
# 21637                         STATE  OTHER STATES          OT         ...
# 21638                         STATE  OTHER STATES          OT         ...
# 21639                         STATE  OTHER STATES          OT         ...
# 21640                         STATE  OTHER STATES          OT         ...
# 21641                         STATE  OTHER STATES          OT         ...
#
#       county_code zip_5 country_code    class_desc domain_desc  \
# 0                               9000   ALL CLASSES       TOTAL
# 1                               9000   ALL CLASSES       TOTAL
# 2                               9000   ALL CLASSES       TOTAL
# 3                               9000   ALL CLASSES       TOTAL
# 4                               9000   ALL CLASSES       TOTAL
# ...           ...   ...          ...           ...         ...
# 21637                           9000  BEE COLONIES       TOTAL
# 21638                           9000  BEE COLONIES       TOTAL
# 21639                           9000  BEE COLONIES       TOTAL
# 21640                           9000  BEE COLONIES       TOTAL
# 21641                           9000  BEE COLONIES       TOTAL
#
#       statisticcat_desc group_desc end_code  year          marketing_id
# 0        PRICE RECEIVED  SPECIALTY       00  2020  MARKETING YEARAL2020
# 1        PRICE RECEIVED  SPECIALTY       00  2019  MARKETING YEARAL2019
# 2        PRICE RECEIVED  SPECIALTY       00  2018  MARKETING YEARAL2018
# 3        PRICE RECEIVED  SPECIALTY       00  2020  MARKETING YEARAZ2020
# 4        PRICE RECEIVED  SPECIALTY       00  2019  MARKETING YEARAZ2019
# ...                 ...        ...      ...   ...                   ...
# 21637         INVENTORY  SPECIALTY       12  2016    OCT THRU DECOT2016
# 21638         INVENTORY  SPECIALTY       03  2015    JAN THRU MAROT2015
# 21639         INVENTORY  SPECIALTY       06  2015    APR THRU JUNOT2015
# 21640         INVENTORY  SPECIALTY       09  2015    JUL THRU SEPOT2015
# 21641         INVENTORY  SPECIALTY       12  2015    OCT THRU DECOT2015
#
# [21642 rows x 41 columns]

# %% [markdown]
# # Capitalized column name for Value

# %%
usda_df['value'] = usda_df['Value']

usda_df
# Out:
#        survey_id freq_desc domaincat_desc asd_desc reference_period_desc  \
# 0              0    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 1              1    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 2              2    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 3              3    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# 4              4    ANNUAL  NOT SPECIFIED                 MARKETING YEAR
# ...          ...       ...            ...      ...                   ...
# 21637      21637   MONTHLY  NOT SPECIFIED                   OCT THRU DEC
# 21638      21638   MONTHLY  NOT SPECIFIED                   JAN THRU MAR
# 21639      21639   MONTHLY  NOT SPECIFIED                   APR THRU JUN
# 21640      21640   MONTHLY  NOT SPECIFIED                   JUL THRU SEP
# 21641      21641   MONTHLY  NOT SPECIFIED                   OCT THRU DEC
#
#       watershed_desc agg_level_desc    state_name state_alpha CV (%)  ...  \
# 0                             STATE       ALABAMA          AL         ...
# 1                             STATE       ALABAMA          AL         ...
# 2                             STATE       ALABAMA          AL         ...
# 3                             STATE       ARIZONA          AZ         ...
# 4                             STATE       ARIZONA          AZ         ...
# ...              ...            ...           ...         ...    ...  ...
# 21637                         STATE  OTHER STATES          OT         ...
# 21638                         STATE  OTHER STATES          OT         ...
# 21639                         STATE  OTHER STATES          OT         ...
# 21640                         STATE  OTHER STATES          OT         ...
# 21641                         STATE  OTHER STATES          OT         ...
#
#       zip_5 country_code    class_desc domain_desc statisticcat_desc  \
# 0                   9000   ALL CLASSES       TOTAL    PRICE RECEIVED
# 1                   9000   ALL CLASSES       TOTAL    PRICE RECEIVED
# 2                   9000   ALL CLASSES       TOTAL    PRICE RECEIVED
# 3                   9000   ALL CLASSES       TOTAL    PRICE RECEIVED
# 4                   9000   ALL CLASSES       TOTAL    PRICE RECEIVED
# ...     ...          ...           ...         ...               ...
# 21637               9000  BEE COLONIES       TOTAL         INVENTORY
# 21638               9000  BEE COLONIES       TOTAL         INVENTORY
# 21639               9000  BEE COLONIES       TOTAL         INVENTORY
# 21640               9000  BEE COLONIES       TOTAL         INVENTORY
# 21641               9000  BEE COLONIES       TOTAL         INVENTORY
#
#       group_desc end_code  year          marketing_id value
# 0      SPECIALTY       00  2020  MARKETING YEARAL2020  5.43
# 1      SPECIALTY       00  2019  MARKETING YEARAL2019  3.38
# 2      SPECIALTY       00  2018  MARKETING YEARAL2018  3.72
# 3      SPECIALTY       00  2020  MARKETING YEARAZ2020  2.18
# 4      SPECIALTY       00  2019  MARKETING YEARAZ2019  2.04
# ...          ...      ...   ...                   ...   ...
# 21637  SPECIALTY       12  2016    OCT THRU DECOT2016     0
# 21638  SPECIALTY       03  2015    JAN THRU MAROT2015     2
# 21639  SPECIALTY       06  2015    APR THRU JUNOT2015    18
# 21640  SPECIALTY       09  2015    JUL THRU SEPOT2015     6
# 21641  SPECIALTY       12  2015    OCT THRU DECOT2015     0
#
# [21642 rows x 42 columns]

# %% [markdown]
# # Removed rows with null values

# %%
usda_df.dropna(inplace=True)

# %% [markdown]
# # Compiled information to be loaded into the location table. Named this dataframe usda_location

# %%
usda_location = usda_df[['country_name', 'country_code', 'state_name', 'state_alpha','state_fips_code', 'marketing_id']]
usda_location
# Out:
#         country_name country_code    state_name state_alpha state_fips_code  \
# 0      UNITED STATES         9000       ALABAMA          AL              01
# 1      UNITED STATES         9000       ALABAMA          AL              01
# 2      UNITED STATES         9000       ALABAMA          AL              01
# 3      UNITED STATES         9000       ARIZONA          AZ              04
# 4      UNITED STATES         9000       ARIZONA          AZ              04
# ...              ...          ...           ...         ...             ...
# 21637  UNITED STATES         9000  OTHER STATES          OT              98
# 21638  UNITED STATES         9000  OTHER STATES          OT              98
# 21639  UNITED STATES         9000  OTHER STATES          OT              98
# 21640  UNITED STATES         9000  OTHER STATES          OT              98
# 21641  UNITED STATES         9000  OTHER STATES          OT              98
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %% [markdown]
# # Compiled information to be loaded into the period table. Named the dataframe usda_period

# %%
usda_period = usda_df[['survey_id','freq_desc','year','load_time','state_name', 'marketing_id']]
usda_period
# Out:
#        survey_id freq_desc  year            load_time    state_name  \
# 0              0    ANNUAL  2020  2021-03-18 15:00:29       ALABAMA
# 1              1    ANNUAL  2019  2021-03-18 15:00:29       ALABAMA
# 2              2    ANNUAL  2018  2020-03-19 15:06:59       ALABAMA
# 3              3    ANNUAL  2020  2021-03-18 15:00:29       ARIZONA
# 4              4    ANNUAL  2019  2021-03-18 15:00:29       ARIZONA
# ...          ...       ...   ...                  ...           ...
# 21637      21637   MONTHLY  2016  2017-08-01 15:00:29  OTHER STATES
# 21638      21638   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21639      21639   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21640      21640   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21641      21641   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %% [markdown]
# # Compiled the information to be loaded into the product table. Named this dataframe usda_product

# %%
usda_product = usda_df[['survey_id','sector_desc','class_desc','group_desc','commodity_desc', 'marketing_id']]
usda_product
# Out:
#        survey_id         sector_desc    class_desc group_desc commodity_desc  \
# 0              0  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 1              1  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 2              2  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 3              3  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 4              4  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# ...          ...                 ...           ...        ...            ...
# 21637      21637  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21638      21638  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21639      21639  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21640      21640  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21641      21641  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %% [markdown]
# # Created a dataframe containing all of the information that will be contained within the various loss of bees tables.

# %%
#General dataframe for loss of bees
usda_causes_df=usda_df[['survey_id','value', 'domain_desc', 'unit_desc','short_desc','statisticcat_desc', 'marketing_id']]
usda_causes_df['short_desc'].unique()
# Out:
# array(['HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#        'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#        'HONEY - PRODUCTION, MEASURED IN $',
#        'HONEY - PRODUCTION, MEASURED IN LB',
#        'HONEY - PRODUCTION, MEASURED IN LB / COLONY',
#        'HONEY - STOCKS, MEASURED IN LB',
#        'HONEY, BEE COLONIES, AFFECTED BY DISEASE - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL VARROA MITES)) - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY VARROA MITES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES - ADDED & REPLACED, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - INVENTORY, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DISORDER, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, DEADOUT, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, DEADOUT, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, RENOVATED - INVENTORY, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES, RENOVATED - INVENTORY, MEASURED IN PCT OF COLONIES'],
#       dtype=object)

# %% [markdown]
# # Created a dataframe for the Colony Collapse Disorder table. This also required the elimination of unneccessary commas and converting the Value column into a type float.

# %%
#Extracted data with CCD for 2020 year (90 rows, 8 columns)
usda_ccd_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("COLONY COLLAPSE DISORDER")]
#Removed "," from value columns
usda_ccd_df['value']=usda_ccd_df['value'].str.replace(',','')
#converted value column in CCD 2020 from str to float
usda_ccd_df['value'] = usda_ccd_df['value'].astype(float)
usda_ccd_df
# Out:
# <ipython-input-13-e4a67f062738>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_ccd_df['value']=usda_ccd_df['value'].str.replace(',','')
# <ipython-input-13-e4a67f062738>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_ccd_df['value'] = usda_ccd_df['value'].astype(float)
#        survey_id   value domain_desc unit_desc  \
# 17562      17562    70.0       TOTAL  COLONIES
# 17563      17563   410.0       TOTAL  COLONIES
# 17564      17564   140.0       TOTAL  COLONIES
# 17565      17565   180.0       TOTAL  COLONIES
# 17566      17566   110.0       TOTAL  COLONIES
# ...          ...     ...         ...       ...
# 17785      17785  1100.0       TOTAL  COLONIES
# 17786      17786  1500.0       TOTAL  COLONIES
# 17787      17787   140.0       TOTAL  COLONIES
# 17788      17788     0.0       TOTAL  COLONIES
# 17789      17789     0.0       TOTAL  COLONIES
#
#                                               short_desc  \
# 17562  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17563  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17564  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17565  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17566  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# ...                                                  ...
# 17785  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17786  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17787  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17788  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17789  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
#
#                     statisticcat_desc        marketing_id
# 17562  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MARAL2020
# 17563  LOSS, COLONY COLLAPSE DISORDER  APR THRU JUNAL2020
# 17564  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MARAL2019
# 17565  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPAL2019
# 17566  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECAL2019
# ...                               ...                 ...
# 17785  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPWY2019
# 17786  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECWY2019
# 17787  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MAROT2019
# 17788  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPOT2019
# 17789  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECOT2019
#
# [228 rows x 7 columns]

# %% [markdown]
# # Similarly created a dataframe for the pests table. This required the same removal of commas and retyping as a float.

# %%
usda_pests_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY PESTS")]
#Removed "," from value columns
usda_pests_df['value']=usda_pests_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_pests_df['value'] = pd.to_numeric(usda_pests_df['value'], errors='coerce')
usda_pests_df
# Out:
# <ipython-input-14-ff02664a4ac4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pests_df['value']=usda_pests_df['value'].str.replace(',','')
# <ipython-input-14-ff02664a4ac4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pests_df['value'] = pd.to_numeric(usda_pests_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 10288      10288    3.4       TOTAL  PCT OF COLONIES
# 10289      10289   18.0       TOTAL  PCT OF COLONIES
# 10290      10290   22.7       TOTAL  PCT OF COLONIES
# 10291      10291   24.6       TOTAL  PCT OF COLONIES
# 10292      10292   26.7       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 11249      11249    9.3       TOTAL  PCT OF COLONIES
# 11250      11250    0.1       TOTAL  PCT OF COLONIES
# 11251      11251    9.1       TOTAL  PCT OF COLONIES
# 11252      11252    0.2       TOTAL  PCT OF COLONIES
# 11253      11253    0.0       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 10288  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 10289  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 10290  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 10291  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 10292  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# ...                                                  ...               ...
# 11249  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 11250  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 11251  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 11252  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 11253  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
#
#              marketing_id
# 10288  JAN THRU MARAL2020
# 10289  APR THRU JUNAL2020
# 10290  JAN THRU MARAL2019
# 10291  JUL THRU SEPAL2019
# 10292  OCT THRU DECAL2019
# ...                   ...
# 11249  OCT THRU DECOT2016
# 11250  JAN THRU MAROT2015
# 11251  APR THRU JUNOT2015
# 11252  JUL THRU SEPOT2015
# 11253  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %%
usda_inventory_max_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("INVENTORY, MAX,")]
#Removed "," from value columns
usda_inventory_max_df['value']=usda_inventory_max_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_inventory_max_df['value'] = pd.to_numeric(usda_inventory_max_df['value'], errors='coerce')
usda_inventory_max_df
# Out:
# <ipython-input-15-a01d5d0615b7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_inventory_max_df['value']=usda_inventory_max_df['value'].str.replace(',','')
# <ipython-input-15-a01d5d0615b7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_inventory_max_df['value'] = pd.to_numeric(usda_inventory_max_df['value'], errors='coerce')
#        survey_id  value domain_desc unit_desc  \
# 16596      16596   8000       TOTAL  COLONIES
# 16597      16597   8500       TOTAL  COLONIES
# 16598      16598   5500       TOTAL  COLONIES
# 16599      16599   7000       TOTAL  COLONIES
# 16600      16600   6000       TOTAL  COLONIES
# ...          ...    ...         ...       ...
# 17557      17557   6460       TOTAL  COLONIES
# 17558      17558   8990       TOTAL  COLONIES
# 17559      17559  11200       TOTAL  COLONIES
# 17560      17560  12280       TOTAL  COLONIES
# 17561      17561  12560       TOTAL  COLONIES
#
#                                               short_desc statisticcat_desc  \
# 16596  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16597  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16598  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16599  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16600  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# ...                                                  ...               ...
# 17557  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17558  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17559  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17560  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17561  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
#
#              marketing_id
# 16596  JAN THRU MARAL2020
# 16597  APR THRU JUNAL2020
# 16598  JAN THRU MARAL2019
# 16599  JUL THRU SEPAL2019
# 16600  OCT THRU DECAL2019
# ...                   ...
# 17557  OCT THRU DECOT2016
# 17558  JAN THRU MAROT2015
# 17559  APR THRU JUNOT2015
# 17560  JUL THRU SEPOT2015
# 17561  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %% [markdown]
# # Also created a dataframe for the inventory_max table. This required the same removal of commas and retyping as a float.

# %%
usda_other_causes_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY OTHER CAUSES")]
#Removed "," from value columns
usda_other_causes_df['value']=usda_other_causes_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_other_causes_df['value'] = pd.to_numeric(usda_other_causes_df['value'], errors='coerce')
usda_other_causes_df
# Out:
# <ipython-input-16-7183846d9813>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_other_causes_df['value']=usda_other_causes_df['value'].str.replace(',','')
# <ipython-input-16-7183846d9813>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_other_causes_df['value'] = pd.to_numeric(usda_other_causes_df['value'], errors='coerce')
#       survey_id  value domain_desc        unit_desc  \
# 8356       8356    1.7       TOTAL  PCT OF COLONIES
# 8357       8357    7.9       TOTAL  PCT OF COLONIES
# 8358       8358    3.1       TOTAL  PCT OF COLONIES
# 8359       8359    9.7       TOTAL  PCT OF COLONIES
# 8360       8360    9.0       TOTAL  PCT OF COLONIES
# ...         ...    ...         ...              ...
# 9317       9317    2.3       TOTAL  PCT OF COLONIES
# 9318       9318    0.9       TOTAL  PCT OF COLONIES
# 9319       9319    0.1       TOTAL  PCT OF COLONIES
# 9320       9320    0.7       TOTAL  PCT OF COLONIES
# 9321       9321    0.0       TOTAL  PCT OF COLONIES
#
#                                              short_desc statisticcat_desc  \
# 8356  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 8357  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 8358  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 8359  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 8360  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# ...                                                 ...               ...
# 9317  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 9318  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 9319  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 9320  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 9321  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
#
#             marketing_id
# 8356  JAN THRU MARAL2020
# 8357  APR THRU JUNAL2020
# 8358  JAN THRU MARAL2019
# 8359  JUL THRU SEPAL2019
# 8360  OCT THRU DECAL2019
# ...                  ...
# 9317  OCT THRU DECOT2016
# 9318  JAN THRU MAROT2015
# 9319  APR THRU JUNOT2015
# 9320  JUL THRU SEPOT2015
# 9321  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %% [markdown]
# # Similarly created a dataframe for the pesticides table. This required the same removal of commas and retyping as a float.

# %%
usda_pesticides_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY PESTICIDES")]
#Removed "," from value columns
usda_pesticides_df['value']=usda_pesticides_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_pesticides_df['value'] = pd.to_numeric(usda_pesticides_df['value'], errors='coerce')
usda_pesticides_df
# Out:
# <ipython-input-17-0add36e41b6d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticides_df['value']=usda_pesticides_df['value'].str.replace(',','')
# <ipython-input-17-0add36e41b6d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticides_df['value'] = pd.to_numeric(usda_pesticides_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 9322        9322    0.1       TOTAL  PCT OF COLONIES
# 9323        9323    7.7       TOTAL  PCT OF COLONIES
# 9324        9324    0.3       TOTAL  PCT OF COLONIES
# 9325        9325    0.2       TOTAL  PCT OF COLONIES
# 9326        9326    4.9       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 10283      10283    9.6       TOTAL  PCT OF COLONIES
# 10284      10284    0.1       TOTAL  PCT OF COLONIES
# 10285      10285    0.0       TOTAL  PCT OF COLONIES
# 10286      10286    0.4       TOTAL  PCT OF COLONIES
# 10287      10287    0.0       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 9322   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 9323   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 9324   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 9325   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 9326   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# ...                                                  ...               ...
# 10283  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 10284  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 10285  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 10286  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 10287  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
#
#              marketing_id
# 9322   JAN THRU MARAL2020
# 9323   APR THRU JUNAL2020
# 9324   JAN THRU MARAL2019
# 9325   JUL THRU SEPAL2019
# 9326   OCT THRU DECAL2019
# ...                   ...
# 10283  OCT THRU DECOT2016
# 10284  JAN THRU MAROT2015
# 10285  APR THRU JUNOT2015
# 10286  JUL THRU SEPOT2015
# 10287  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %% [markdown]
# # Also created a dataframe for the disease table. This required the same removal of commas and retyping as a float.

# %%
usda_disease_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY DISEASE")]
#Removed "," from value columns
usda_disease_df['value']=usda_disease_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_disease_df['value'] = pd.to_numeric(usda_disease_df['value'], errors='coerce')
usda_disease_df.dropna(inplace=True)
usda_disease_df
# Out:
# <ipython-input-18-c4308274e7e7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df['value']=usda_disease_df['value'].str.replace(',','')
# <ipython-input-18-c4308274e7e7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df['value'] = pd.to_numeric(usda_disease_df['value'], errors='coerce')
# <ipython-input-18-c4308274e7e7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df.dropna(inplace=True)
#       survey_id  value domain_desc        unit_desc  \
# 7391       7391    1.6       TOTAL  PCT OF COLONIES
# 7392       7392    1.8       TOTAL  PCT OF COLONIES
# 7393       7393    2.9       TOTAL  PCT OF COLONIES
# 7394       7394    0.6       TOTAL  PCT OF COLONIES
# 7395       7395    1.9       TOTAL  PCT OF COLONIES
# ...         ...    ...         ...              ...
# 8351       8351    9.3       TOTAL  PCT OF COLONIES
# 8352       8352    0.0       TOTAL  PCT OF COLONIES
# 8353       8353    0.0       TOTAL  PCT OF COLONIES
# 8354       8354    0.0       TOTAL  PCT OF COLONIES
# 8355       8355    0.0       TOTAL  PCT OF COLONIES
#
#                                              short_desc statisticcat_desc  \
# 7391  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7392  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7393  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7394  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7395  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# ...                                                 ...               ...
# 8351  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8352  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8353  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8354  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8355  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
#
#             marketing_id
# 7391  APR THRU JUNAL2020
# 7392  JAN THRU MARAL2019
# 7393  JUL THRU SEPAL2019
# 7394  OCT THRU DECAL2019
# 7395  JAN THRU MARAL2018
# ...                  ...
# 8351  OCT THRU DECOT2016
# 8352  JAN THRU MAROT2015
# 8353  APR THRU JUNOT2015
# 8354  JUL THRU SEPOT2015
# 8355  OCT THRU DECOT2015
#
# [946 rows x 7 columns]

# %% [markdown]
# # Additionally created a dataframe for the varroa_mites table. This required the same removal of commas and retyping as a float.

# %%
usda_varroa_mites_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY VARROA MITES")]
#Removed "," from value columns
usda_varroa_mites_df['value']=usda_varroa_mites_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_varroa_mites_df['value'] = pd.to_numeric(usda_varroa_mites_df['value'], errors='coerce')
usda_varroa_mites_df
# Out:
# <ipython-input-19-a377c11b86e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_varroa_mites_df['value']=usda_varroa_mites_df['value'].str.replace(',','')
# <ipython-input-19-a377c11b86e0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_varroa_mites_df['value'] = pd.to_numeric(usda_varroa_mites_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 12220      12220   12.4       TOTAL  PCT OF COLONIES
# 12221      12221   28.5       TOTAL  PCT OF COLONIES
# 12222      12222   27.2       TOTAL  PCT OF COLONIES
# 12223      12223   30.6       TOTAL  PCT OF COLONIES
# 12224      12224   46.7       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 13181      13181   24.1       TOTAL  PCT OF COLONIES
# 13182      13182    0.8       TOTAL  PCT OF COLONIES
# 13183      13183   36.3       TOTAL  PCT OF COLONIES
# 13184      13184    8.8       TOTAL  PCT OF COLONIES
# 13185      13185    8.2       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 12220  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12221  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12222  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12223  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12224  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# ...                                                  ...               ...
# 13181  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13182  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13183  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13184  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13185  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
#
#              marketing_id
# 12220  JAN THRU MARAL2020
# 12221  APR THRU JUNAL2020
# 12222  JAN THRU MARAL2019
# 12223  JUL THRU SEPAL2019
# 12224  OCT THRU DECAL2019
# ...                   ...
# 13181  OCT THRU DECOT2016
# 13182  JAN THRU MAROT2015
# 13183  APR THRU JUNOT2015
# 13184  JUL THRU SEPOT2015
# 13185  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %% [markdown]
# # Finally, created a dataframe for the pests table. This required the same removal of commas and retyping as a float.

# %%
usda_unknown_causes_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY UNKNOWN CAUSES")]
#Removed "," from value columns
usda_unknown_causes_df['value']=usda_unknown_causes_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_unknown_causes_df['value'] = pd.to_numeric(usda_unknown_causes_df['value'], errors='coerce')
usda_unknown_causes_df
# Out:
# <ipython-input-20-c2232f0d4a40>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_unknown_causes_df['value']=usda_unknown_causes_df['value'].str.replace(',','')
# <ipython-input-20-c2232f0d4a40>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_unknown_causes_df['value'] = pd.to_numeric(usda_unknown_causes_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 11254      11254    4.3       TOTAL  PCT OF COLONIES
# 11255      11255    9.5       TOTAL  PCT OF COLONIES
# 11256      11256    9.0       TOTAL  PCT OF COLONIES
# 11257      11257    6.4       TOTAL  PCT OF COLONIES
# 11258      11258   11.3       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 12215      12215    1.4       TOTAL  PCT OF COLONIES
# 12216      12216    0.0       TOTAL  PCT OF COLONIES
# 12217      12217    0.0       TOTAL  PCT OF COLONIES
# 12218      12218    0.2       TOTAL  PCT OF COLONIES
# 12219      12219    8.0       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 11254  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 11255  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 11256  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 11257  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 11258  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# ...                                                  ...               ...
# 12215  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 12216  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 12217  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 12218  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 12219  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
#
#              marketing_id
# 11254  JAN THRU MARAL2020
# 11255  APR THRU JUNAL2020
# 11256  JAN THRU MARAL2019
# 11257  JUL THRU SEPAL2019
# 11258  OCT THRU DECAL2019
# ...                   ...
# 12215  OCT THRU DECOT2016
# 12216  JAN THRU MAROT2015
# 12217  APR THRU JUNOT2015
# 12218  JUL THRU SEPOT2015
# 12219  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %% [markdown]
# # Imprted modules needed for creation of tables in postgresql

# %%
import requests
import numpy as np
import pandas as pd
import time
from pprint import pprint
from matplotlib import pyplot as plt
from scipy import stats
import psycopg2
import time
import pandas as pd
from sqlalchemy import create_engine
import psycopg2.extras as extras
import io

# %%
#connecting python to postgres sql
#loopback host ip="127.0.0.1". can also be used to be specific.

# %% [markdown]
# # Created a function called load which will be used to create the tables and populate them with the dataframes which are saved in csv files.

# %%
def load(df, name):
    #postgresql
    engine = create_engine('redshift+psycopg2://postgres:trimpu88@127.0.0.1:5433/postgres')
    #engine = psycopg2.connect(database="postgres", user="postgres", password="trimpu88", host="localhost", port="5433")
    #engine = create_engine('postgresql+psycopg2://username:password@host:port/database')

    df.head(0).to_sql( name, engine, if_exists='replace',index=False) #drops old table and creates new empty table

    conn = engine.raw_connection()
    cur = conn.cursor()
    output = io.StringIO()
    df.to_csv(output, sep='\t', header=False, index=False)
    output.seek(0)
    contents = output.getvalue()
    cur.copy_from(output, name, null="") # null values become ''
    conn.commit()
    print(str(name) + ' done')

# %% [markdown]
# # Created the csv files which will be loaded into postgresql

# %%
usda_location.to_csv('location.csv', index=False)
usda_period.to_csv('period.csv', index=False)
usda_product.to_csv('product.csv', index=False)
usda_ccd_df.to_csv('ccd.csv', index=False)
usda_pests_df.to_csv('pests.csv', index=False)
usda_inventory_max_df.to_csv('inventory_max.csv', index=False)
usda_other_causes_df.to_csv('other_causes.csv', index=False)
usda_pesticides_df.to_csv('pesticides.csv', index=False)
usda_disease_df.to_csv('disease.csv', index=False)
usda_unknown_causes_df.to_csv('unknown_causes.csv', index=False)
usda_varroa_mites_df.to_csv('varroa_mites.csv', index=False)

# %% [markdown]
# # Created each table and populated it with the information via the function created above

# %%
load(usda_period, 'period')
load(usda_product, 'product')
load(usda_ccd_df, 'colony_collapse_disorder')
load(usda_inventory_max_df, 'inventory_max')
load(usda_other_causes_df, 'other_causes')
load(usda_pests_df, 'pests')
load(usda_varroa_mites_df, 'varroa_mites')
load(usda_unknown_causes_df, 'unknown_causes')
load(usda_pesticides_df, 'pesticides')
load(usda_disease_df, 'disease')
load(usda_location, 'location')

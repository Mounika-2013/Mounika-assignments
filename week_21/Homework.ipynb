# %% [markdown]
# 3. What kind of API did you build? What types of APIs are there? Why are APIs important?

# %%
We accessed loop back address with http request. And used different endpoints in a single API. 
So, its a composite API. 
Different types include:
    1. Web API - Accessed with http protocol to communicate with browser. 
    2. Open API - Ex. these are the API's that we used to fetch data during our projects. Where there are restrictions and sometimes need prior registration. 
    3. Internal API - these are specific to companies. Can be accessed only within companies network 
    4. Partner API - Restricted access and often controlled through third-party API
    5. Composite API - Several endpoints can be accessed with single API. This reduces server load and improves perfomrnace.
    
Importance:
    1. Saves time - As it avoids building application from scartch. One can use it make further changes. 
    2. Business growth - Companies use API's from other companies to make things work. Ex: While purchasing an item customer pays through Master card credit card. The store application uses Master card APIs to get the transactions done. 
    3. Integration - Not all the UI's are same to integrate. API does the work .

# %% [markdown]
# Screenshot for question 2

# %%
from IPython import display
display.Image("/Users/trimpu/Downloads/API_pic.jpg")
